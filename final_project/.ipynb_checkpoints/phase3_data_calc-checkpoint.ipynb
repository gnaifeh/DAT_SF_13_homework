# %% [markdown]
# # Final Project: Phase 3: Manipulating Maps Data with Pandas

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import MySQLdb as mdb
import MySQL_data_file as MySQL_data
from datetime import datetime,time,timedelta
from dateutil.parser import parse

# %%
con = mdb.connect(MySQL_data.my_sql_host, MySQL_data.my_sql_user,\
                    MySQL_data.my_sql_passwd,\
                    MySQL_data.my_sql_database)
#con.close

# %%
def run_sql(query):
    cur = con.cursor()
    cur.execute(query)
    con.commit()
    #con.close()
    return cur.fetchall()

# %% [markdown]
# ####Read in the data from MySQL and combine into a single DataFrame

# %%
gmaps_df = pd.read_sql("""SELECT entry_id,timestamp,datetime,origins,destinations,travel_mode,duration,distance,fare
                        FROM gmaps_data""",con)
bing_df = pd.read_sql("""SELECT entry_id,timestamp,datetime,origins,destinations,travel_mode,duration_traffic,distance * 1000,congestion
                        FROM mmaps_data""",con)
#changing the bing maps "duration_traffic" column to "duration" in order to match up the column with the gmaps_df
bing_df.columns = [u'entry_id', u'timestamp', u'datetime', u'origins', u'destinations', u'travel_mode', u'duration', u'distance', u'congestion']
#merging the two dataframes
combined_df = gmaps_df.merge(bing_df, how='outer')
#sorting the combined df by datetime
combined_df.sort(columns='datetime', inplace=True)
#reindexing the combined df to have chronological index
combined_df.index = np.arange(len(combined_df))
#print len(combined_df)
#combined_df.head()

# %% [markdown]
# ####Save MySQL data as a CSV file and read in the CSV

# %%
combined_df.to_csv('ignore/sat_may16_afternoon_import.csv')

# %%
combined_df = pd.read_csv('ignore/sat_may16_afternoon_import.csv')

# %% [markdown]
# Rename columns of imported csv file. Drop redundant columns.

# %%
imported_combined_df = combined_df.copy()

# %%
imported_combined_df.columns = [u'pd_id', u'entry_id', u'timestamp', u'datetime', u'origins', u'destinations', u'travel_mode', u'duration', u'distance', u'fare', u'congestion']
imported_combined_df.drop(['entry_id','timestamp'], axis=1, inplace=True) #drop redundant entry_id's from MYSQL and replace with distinct pandas_id's

# %% [markdown]
# Remove all rows in the Combined DataFrame where duration is Null

# %%
#can also use sql to look for null values: select * from gmaps_data where duration is NULL
imported_combined_df = imported_combined_df.ix[pd.notnull(combined_df['duration']),:]
imported_combined_df.sort(columns='pd_id', ascending=True, inplace=True)

# %%
#compare total rows of current df with not null rows of previous df
#print len(combined_df[pd.isnull(combined_df['duration'])])
#print len(combined_df[pd.notnull(combined_df['duration'])])
print len(imported_combined_df)
# Out:
# 69740

# %% [markdown]
# Remove all rows in the Combined DataFrame where duration is "0" (e.g. Oakland to Oakland)

# %%
#below code prints number of trips from Oakland to Oakland
#print len(imported_combined_df[((imported_combined_df['origins'] =='Oakland, CA, USA') & (imported_combined_df['destinations'] == 'Oakland, CA, USA'))])

# %%
imported_combined_df = imported_combined_df[combined_df['distance'] != 0]
#print len(imported_combined_df)
#code below prints out number of trips that are not from Oakland to Oakland
print len(imported_combined_df[((imported_combined_df['origins'] !='Oakland, CA, USA') | (imported_combined_df['destinations'] != 'Oakland, CA, USA'))])
# Out:
# 69242

# %% [markdown]
# Convert (or rather) re-convert datetime column to numpy datetime format using pandas to_datetime function

# %%
imported_combined_df['datetime'] = pd.to_datetime(imported_combined_df['datetime']) #Note still in UTC time zone

# %%
imported_combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69242 entries, 0 to 69923
# Data columns (total 9 columns):
# pd_id           69242 non-null int64
# datetime        69242 non-null datetime64[ns]
# origins         69242 non-null object
# destinations    69242 non-null object
# travel_mode     69242 non-null object
# duration        69242 non-null float64
# distance        69242 non-null float64
# fare            23432 non-null float64
# congestion      29688 non-null object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 5.3+ MB

# %% [markdown]
# ####Normalizing origin/destination names by replacing with shorter names

# %%
#The following code displays/stores the distinct names in the origins and destinations
origins_sorted = np.sort(pd.Series.unique(imported_combined_df['origins']))
destinations_sorted = np.sort(pd.Series.unique(imported_combined_df['destinations']))
#print len(origins_sorted); print len(destinations_sorted)

# %%
#this is the list of names that will be replacing longer names for origins/destinations
replacement_names = ['Oakland','Berkeley', 'Financial District', 'Mission',\
                     'Mountain View', 'Noe Valley', 'North Beach', 'Russian Hill',\
                     'Pacific Heights', 'Outer Sunset', 'Outer Richmond']

# %%
#the following code normalizes the district and city names in the origin and destination columns,
#replaces longer names with shorter names from list above
for short_name in replacement_names:
    imported_combined_df.ix[imported_combined_df['origins'].str.contains(short_name), 'origins'] = short_name
    imported_combined_df.ix[imported_combined_df['destinations'].str.contains(short_name), 'destinations'] = short_name

# %%
#check to make sure that name normalization was successful
##################################
#print np.sort(pd.Series.unique(imported_combined_df['origins']))
#print np.sort(pd.Series.unique(imported_combined_df['destinations']))
##################################
#making sure that there were no incidents in updating the origins and destinations
#by looking to see if any origin/destination pairs are equivalent
#len(imported_combined_df[imported_combined_df['origins'] != imported_combined_df['destinations']])

# %% [markdown]
# ####Reindex the DataFrame using the 'datetime' column

# %%
imported_combined_df.index = imported_combined_df['datetime'].values

# %%
imported_combined_df.index = imported_combined_df.index.tz_localize('UTC')

# %%
imported_combined_df.index = imported_combined_df.index.tz_convert('US/Pacific')

# %%
imported_combined_df.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2015-04-20 01:14:42-07:00, ..., 2015-05-16 11:00:06-07:00]
# Length: 69242, Freq: None, Timezone: US/Pacific

# %%
imported_combined_df.sort_index(axis=0, ascending=True, inplace=True)

# %%
imported_combined_df.sort(columns=['datetime','origins','destinations','travel_mode'], inplace=True)
#this would display better after resampling (or at least removing seconds data)

# %%
imported_combined_df.tail(53)
# Out:
#                            pd_id            datetime          origins  \
# 2015-05-16 10:45:06-07:00  69870 2015-05-16 17:45:06         Berkeley
# 2015-05-16 11:00:01-07:00  69872 2015-05-16 18:00:01     Russian Hill
# 2015-05-16 11:00:02-07:00  69904 2015-05-16 18:00:02         Berkeley
# 2015-05-16 11:00:02-07:00  69897 2015-05-16 18:00:02         Berkeley
# 2015-05-16 11:00:02-07:00  69895 2015-05-16 18:00:02         Berkeley
# 2015-05-16 11:00:02-07:00  69881 2015-05-16 18:00:02          Mission
# 2015-05-16 11:00:02-07:00  69880 2015-05-16 18:00:02          Mission
# 2015-05-16 11:00:02-07:00  69882 2015-05-16 18:00:02          Mission
# 2015-05-16 11:00:02-07:00  69878 2015-05-16 18:00:02       Noe Valley
# 2015-05-16 11:00:02-07:00  69877 2015-05-16 18:00:02       Noe Valley
# 2015-05-16 11:00:02-07:00  69879 2015-05-16 18:00:02       Noe Valley
# 2015-05-16 11:00:02-07:00  69901 2015-05-16 18:00:02      North Beach
# 2015-05-16 11:00:02-07:00  69896 2015-05-16 18:00:02      North Beach
# 2015-05-16 11:00:02-07:00  69902 2015-05-16 18:00:02      North Beach
# 2015-05-16 11:00:02-07:00  69892 2015-05-16 18:00:02      North Beach
# 2015-05-16 11:00:02-07:00  69900 2015-05-16 18:00:02      North Beach
# 2015-05-16 11:00:02-07:00  69893 2015-05-16 18:00:02      North Beach
# 2015-05-16 11:00:02-07:00  69876 2015-05-16 18:00:02          Oakland
# 2015-05-16 11:00:02-07:00  69874 2015-05-16 18:00:02          Oakland
# 2015-05-16 11:00:02-07:00  69887 2015-05-16 18:00:02   Outer Richmond
# 2015-05-16 11:00:02-07:00  69886 2015-05-16 18:00:02   Outer Richmond
# 2015-05-16 11:00:02-07:00  69888 2015-05-16 18:00:02   Outer Richmond
# 2015-05-16 11:00:02-07:00  69884 2015-05-16 18:00:02     Outer Sunset
# 2015-05-16 11:00:02-07:00  69883 2015-05-16 18:00:02     Outer Sunset
# 2015-05-16 11:00:02-07:00  69885 2015-05-16 18:00:02     Outer Sunset
# 2015-05-16 11:00:02-07:00  69890 2015-05-16 18:00:02  Pacific Heights
# 2015-05-16 11:00:02-07:00  69889 2015-05-16 18:00:02  Pacific Heights
# 2015-05-16 11:00:02-07:00  69903 2015-05-16 18:00:02  Pacific Heights
# 2015-05-16 11:00:02-07:00  69891 2015-05-16 18:00:02  Pacific Heights
# 2015-05-16 11:00:02-07:00  69898 2015-05-16 18:00:02     Russian Hill
# 2015-05-16 11:00:02-07:00  69875 2015-05-16 18:00:02     Russian Hill
# 2015-05-16 11:00:02-07:00  69899 2015-05-16 18:00:02     Russian Hill
# 2015-05-16 11:00:02-07:00  69894 2015-05-16 18:00:02     Russian Hill
# 2015-05-16 11:00:02-07:00  69873 2015-05-16 18:00:02     Russian Hill
# 2015-05-16 11:00:03-07:00  69906 2015-05-16 18:00:03   Outer Richmond
# 2015-05-16 11:00:03-07:00  69907 2015-05-16 18:00:03   Outer Richmond
# 2015-05-16 11:00:03-07:00  69910 2015-05-16 18:00:03   Outer Richmond
# 2015-05-16 11:00:03-07:00  69905 2015-05-16 18:00:03     Outer Sunset
# 2015-05-16 11:00:03-07:00  69909 2015-05-16 18:00:03  Pacific Heights
# 2015-05-16 11:00:03-07:00  69908 2015-05-16 18:00:03  Pacific Heights
# 2015-05-16 11:00:04-07:00  69914 2015-05-16 18:00:04          Mission
# 2015-05-16 11:00:04-07:00  69915 2015-05-16 18:00:04          Mission
# 2015-05-16 11:00:04-07:00  69913 2015-05-16 18:00:04          Mission
# 2015-05-16 11:00:04-07:00  69916 2015-05-16 18:00:04       Noe Valley
# 2015-05-16 11:00:04-07:00  69911 2015-05-16 18:00:04     Outer Sunset
# 2015-05-16 11:00:04-07:00  69912 2015-05-16 18:00:04     Outer Sunset
# 2015-05-16 11:00:05-07:00  69918 2015-05-16 18:00:05       Noe Valley
# 2015-05-16 11:00:05-07:00  69919 2015-05-16 18:00:05       Noe Valley
# 2015-05-16 11:00:05-07:00  69917 2015-05-16 18:00:05          Oakland
# 2015-05-16 11:00:05-07:00  69920 2015-05-16 18:00:05          Oakland
# 2015-05-16 11:00:06-07:00  69923 2015-05-16 18:00:06         Berkeley
# 2015-05-16 11:00:06-07:00  69921 2015-05-16 18:00:06         Berkeley
# 2015-05-16 11:00:06-07:00  69922 2015-05-16 18:00:06         Berkeley
#
#                                  destinations travel_mode  duration  distance  \
# 2015-05-16 10:45:06-07:00       Mountain View     driving      3718     74000
# 2015-05-16 11:00:01-07:00             Oakland     driving      1797     19000
# 2015-05-16 11:00:02-07:00  Financial District     transit      1831     19043
# 2015-05-16 11:00:02-07:00       Mountain View     transit      6060     81029
# 2015-05-16 11:00:02-07:00             Oakland     transit      1560      9092
# 2015-05-16 11:00:02-07:00  Financial District     transit      1377      5135
# 2015-05-16 11:00:02-07:00       Mountain View     transit      4979     59671
# 2015-05-16 11:00:02-07:00             Oakland     transit      2879     17529
# 2015-05-16 11:00:02-07:00  Financial District     transit      2088      7210
# 2015-05-16 11:00:02-07:00       Mountain View     transit      5166     58747
# 2015-05-16 11:00:02-07:00             Oakland     transit      3221     19495
# 2015-05-16 11:00:02-07:00  Financial District     driving       398      2000
# 2015-05-16 11:00:02-07:00  Financial District     transit      1097      2727
# 2015-05-16 11:00:02-07:00       Mountain View     driving      3332     67000
# 2015-05-16 11:00:02-07:00       Mountain View     transit      5546     62689
# 2015-05-16 11:00:02-07:00             Oakland     driving      1526     19000
# 2015-05-16 11:00:02-07:00             Oakland     transit      2927     15670
# 2015-05-16 11:00:02-07:00  Financial District     transit      2482     13508
# 2015-05-16 11:00:02-07:00       Mountain View     transit      7860     80855
# 2015-05-16 11:00:02-07:00  Financial District     transit      2945      9427
# 2015-05-16 11:00:02-07:00       Mountain View     transit      8459     68118
# 2015-05-16 11:00:02-07:00             Oakland     transit      4454     22217
# 2015-05-16 11:00:02-07:00  Financial District     transit      3011     11400
# 2015-05-16 11:00:02-07:00       Mountain View     transit      6242     62376
# 2015-05-16 11:00:02-07:00             Oakland     transit      4562     31571
# 2015-05-16 11:00:02-07:00  Financial District     transit      1727      3886
# 2015-05-16 11:00:02-07:00       Mountain View     transit      5943     64921
# 2015-05-16 11:00:02-07:00             Oakland     driving      1943     21000
# 2015-05-16 11:00:02-07:00             Oakland     transit      3531     17451
# 2015-05-16 11:00:02-07:00  Financial District     driving       621      3000
# 2015-05-16 11:00:02-07:00  Financial District     transit      1556      3016
# 2015-05-16 11:00:02-07:00       Mountain View     driving      3376     66000
# 2015-05-16 11:00:02-07:00       Mountain View     transit      5277     62895
# 2015-05-16 11:00:02-07:00             Oakland     transit      3356     16804
# 2015-05-16 11:00:03-07:00  Financial District     driving      1869     10000
# 2015-05-16 11:00:03-07:00       Mountain View     driving      3351     67000
# 2015-05-16 11:00:03-07:00             Oakland     driving      2418     27000
# 2015-05-16 11:00:03-07:00             Oakland     driving      2324     36000
# 2015-05-16 11:00:03-07:00  Financial District     driving       807      4000
# 2015-05-16 11:00:03-07:00       Mountain View     driving      3334     66000
# 2015-05-16 11:00:04-07:00  Financial District     driving      1373      6000
# 2015-05-16 11:00:04-07:00       Mountain View     driving      2658     61000
# 2015-05-16 11:00:04-07:00             Oakland     driving      1446     21000
# 2015-05-16 11:00:04-07:00             Oakland     driving      1802     24000
# 2015-05-16 11:00:04-07:00  Financial District     driving      2174     23000
# 2015-05-16 11:00:04-07:00       Mountain View     driving      2980     65000
# 2015-05-16 11:00:05-07:00  Financial District     driving      1640     10000
# 2015-05-16 11:00:05-07:00       Mountain View     driving      2847     61000
# 2015-05-16 11:00:05-07:00  Financial District     driving      1387     18000
# 2015-05-16 11:00:05-07:00       Mountain View     driving      2940     65000
# 2015-05-16 11:00:06-07:00  Financial District     driving      1779     20000
# 2015-05-16 11:00:06-07:00       Mountain View     driving      3715     74000
# 2015-05-16 11:00:06-07:00             Oakland     driving      1143      9000
#
#                            fare congestion
# 2015-05-16 10:45:06-07:00   NaN       None
# 2015-05-16 11:00:01-07:00   NaN       Mild
# 2015-05-16 11:00:02-07:00     4        NaN
# 2015-05-16 11:00:02-07:00    10        NaN
# 2015-05-16 11:00:02-07:00   NaN        NaN
# 2015-05-16 11:00:02-07:00     2        NaN
# 2015-05-16 11:00:02-07:00    10        NaN
# 2015-05-16 11:00:02-07:00   NaN        NaN
# 2015-05-16 11:00:02-07:00     2        NaN
# 2015-05-16 11:00:02-07:00    10        NaN
# 2015-05-16 11:00:02-07:00   NaN        NaN
# 2015-05-16 11:00:02-07:00   NaN     Medium
# 2015-05-16 11:00:02-07:00     2        NaN
# 2015-05-16 11:00:02-07:00   NaN       Mild
# 2015-05-16 11:00:02-07:00    10        NaN
# 2015-05-16 11:00:02-07:00   NaN       Mild
# 2015-05-16 11:00:02-07:00   NaN        NaN
# 2015-05-16 11:00:02-07:00   NaN        NaN
# 2015-05-16 11:00:02-07:00   NaN        NaN
# 2015-05-16 11:00:02-07:00     2        NaN
# 2015-05-16 11:00:02-07:00    12        NaN
# 2015-05-16 11:00:02-07:00   NaN        NaN
# 2015-05-16 11:00:02-07:00     2        NaN
# 2015-05-16 11:00:02-07:00    12        NaN
# 2015-05-16 11:00:02-07:00   NaN        NaN
# 2015-05-16 11:00:02-07:00     2        NaN
# 2015-05-16 11:00:02-07:00    10        NaN
# 2015-05-16 11:00:02-07:00   NaN       Mild
# 2015-05-16 11:00:02-07:00   NaN        NaN
# 2015-05-16 11:00:02-07:00   NaN     Medium
# 2015-05-16 11:00:02-07:00     8        NaN
# 2015-05-16 11:00:02-07:00   NaN       Mild
# 2015-05-16 11:00:02-07:00    10        NaN
# 2015-05-16 11:00:02-07:00   NaN        NaN
# 2015-05-16 11:00:03-07:00   NaN     Medium
# 2015-05-16 11:00:03-07:00   NaN       Mild
# 2015-05-16 11:00:03-07:00   NaN     Medium
# 2015-05-16 11:00:03-07:00   NaN       Mild
# 2015-05-16 11:00:03-07:00   NaN     Medium
# 2015-05-16 11:00:03-07:00   NaN       Mild
# 2015-05-16 11:00:04-07:00   NaN     Medium
# 2015-05-16 11:00:04-07:00   NaN       None
# 2015-05-16 11:00:04-07:00   NaN       Mild
# 2015-05-16 11:00:04-07:00   NaN       Mild
# 2015-05-16 11:00:04-07:00   NaN     Medium
# 2015-05-16 11:00:04-07:00   NaN       None
# 2015-05-16 11:00:05-07:00   NaN       Mild
# 2015-05-16 11:00:05-07:00   NaN       None
# 2015-05-16 11:00:05-07:00   NaN     Medium
# 2015-05-16 11:00:05-07:00   NaN       None
# 2015-05-16 11:00:06-07:00   NaN       Mild
# 2015-05-16 11:00:06-07:00   NaN       None
# 2015-05-16 11:00:06-07:00   NaN       Mild

# %% [markdown]
# ####Separate data by transit/driving. Create transit DataFrame and driving DataFrame for all data.

# %% [markdown]
# Note: It is necessary to separate out data by transit/driving because only one of the two would be used after resampling is implemented

# %%
transit_all = imported_combined_df[imported_combined_df['travel_mode'] == 'transit']
transit_all.head()
# Out:
#                            pd_id            datetime          origins  \
# 2015-04-20 01:14:42-07:00      2 2015-04-20 08:14:42       Noe Valley
# 2015-04-20 01:14:42-07:00      3 2015-04-20 08:14:42       Noe Valley
# 2015-04-20 01:14:42-07:00      0 2015-04-20 08:14:42     Outer Sunset
# 2015-04-20 01:14:42-07:00      1 2015-04-20 08:14:42     Outer Sunset
# 2015-04-20 01:14:42-07:00      4 2015-04-20 08:14:42  Pacific Heights
#
#                                  destinations travel_mode  duration  distance  \
# 2015-04-20 01:14:42-07:00  Financial District     transit      3182      9355
# 2015-04-20 01:14:42-07:00             Oakland     transit      3305     19461
# 2015-04-20 01:14:42-07:00  Financial District     transit      2661     11969
# 2015-04-20 01:14:42-07:00             Oakland     transit      6056     30158
# 2015-04-20 01:14:42-07:00  Financial District     transit      1232      4048
#
#                            fare congestion
# 2015-04-20 01:14:42-07:00     2        NaN
# 2015-04-20 01:14:42-07:00   NaN        NaN
# 2015-04-20 01:14:42-07:00     2        NaN
# 2015-04-20 01:14:42-07:00   NaN        NaN
# 2015-04-20 01:14:42-07:00     2        NaN

# %%
driving_all = imported_combined_df[imported_combined_df['travel_mode'] == 'driving']
driving_all.head()
# Out:
#                            pd_id            datetime  origins  \
# 2015-04-27 02:32:56-07:00  10483 2015-04-27 09:32:56  Oakland
# 2015-04-27 02:32:56-07:00  10486 2015-04-27 09:32:56  Oakland
# 2015-04-27 02:32:56-07:00  10485 2015-04-27 09:32:56  Oakland
# 2015-04-27 02:32:56-07:00  10484 2015-04-27 09:32:56  Oakland
# 2015-04-27 02:32:56-07:00  10482 2015-04-27 09:32:56  Oakland
#
#                               destinations travel_mode  duration  distance  \
# 2015-04-27 02:32:56-07:00          Mission     driving      1397     20000
# 2015-04-27 02:32:56-07:00       Noe Valley     driving      1576     24000
# 2015-04-27 02:32:56-07:00   Outer Richmond     driving      2089     27000
# 2015-04-27 02:32:56-07:00     Outer Sunset     driving      2097     36000
# 2015-04-27 02:32:56-07:00  Pacific Heights     driving      1750     23000
#
#                            fare congestion
# 2015-04-27 02:32:56-07:00   NaN       Mild
# 2015-04-27 02:32:56-07:00   NaN       None
# 2015-04-27 02:32:56-07:00   NaN       None
# 2015-04-27 02:32:56-07:00   NaN       None
# 2015-04-27 02:32:56-07:00   NaN       None

# %%
#print len(transit_all); print len(driving_all); print len(transit_all) + len(driving_all); print len(imported_combined_df)

# %% [markdown]
# ####Create Metaframe which separates data by travel_mode and origin/destination pairs

# %%
#create a function (which will work for both transit and driving DFs):
#create the metaframe
#for each origin/destination pair,
#     create a dataframe
#     resample the dataframe
#Question to self==should i delete NaT values that appear after resampling NOTE: MAY DO THIS ON A ONE OFF BASIS
#add a date column (to be used for train/test splits and crossvalidation) SUCCESS
#add a time column (rounded to the minute) SUCCESS
#store this in a dataframe (meta frame!!!) SUCCESS

# %%
meta_frame = pd.DataFrame(index=pd.MultiIndex.from_product([['to'],replacement_names]),\
                          columns=pd.MultiIndex.from_product([['driving','transit'],['from'],replacement_names]))

# %%
travel_mode_list = ['driving','transit']
for this_origin in replacement_names:
    for this_destination in replacement_names:
        if len(imported_combined_df[(imported_combined_df['origins'] == this_origin) &\
                                 (imported_combined_df['destinations'] == this_destination)]) > 0:
            for this_travel_mode in travel_mode_list:
                current_df = imported_combined_df[(imported_combined_df['travel_mode'] == this_travel_mode) &\
                                             (imported_combined_df['origins'] == this_origin) &\
                                            (imported_combined_df['destinations'] == this_destination)].copy()
                current_df = current_df.resample('15min',how='first',closed='left', label='left')
                current_df['time_col'] = [current_df.index[x].time() for x in xrange(len(current_df))]
                current_df['time_str_col'] = [x.strftime('%I:%M') for x in current_df.index]
                current_df['date_col'] = [current_df.index[x].date() for x in xrange(len(current_df))]
                meta_frame[this_travel_mode]['from'][this_origin]['to'][this_destination] = current_df

# %%
#meta_frame.head()

# %%
#meta_frame['driving']['from']['Berkeley']['to']['Mountain View'].ix['5/05/2015 4:20':,:].head()

# %% [markdown]
# ####Create new functions:
# custom_times_index: returns a new df with times as index (removes dates)<br />
# custom_remove_nat: returns a new df without all of the rows with NaT<br />
# cutsom_remove_wknd: returns a new df with only data from weekdays<br />

# %% [markdown]
# Function to: Remove NaT rows from individual origin/destination dataframe

# %%
def custom_remove_nat(current_df):
    return current_df[current_df['duration'].notnull()].copy()

# %%
current_df = meta_frame['driving']['from']['Berkeley']['to']['Mountain View']

# %%
current_df = custom_remove_nat(current_df)

# %%
#current_df.head()

# %% [markdown]
# Function to: Remove weekends and return new df

# %%
current_df = meta_frame['driving']['from']['Berkeley']['to']['Mountain View']

# %%
def custom_remove_wknd(current_df):
    return current_df[(current_df.index.weekday != 5) & (current_df.index.weekday != 6)].copy()

# %%
current_df = custom_remove_wknd(current_df)
current_df.date_col.unique()
# Out:
# array([datetime.date(2015, 4, 27), datetime.date(2015, 4, 28),
#        datetime.date(2015, 4, 29), datetime.date(2015, 4, 30),
#        datetime.date(2015, 5, 1), datetime.date(2015, 5, 4),
#        datetime.date(2015, 5, 5), datetime.date(2015, 5, 6),
#        datetime.date(2015, 5, 7), datetime.date(2015, 5, 8),
#        datetime.date(2015, 5, 11), datetime.date(2015, 5, 12),
#        datetime.date(2015, 5, 13), datetime.date(2015, 5, 14),
#        datetime.date(2015, 5, 15)], dtype=object)

# %% [markdown]
# Function to: Change index from dates to times (and return new df)

# %%
def custom_times_index(current_df):
    current_df.index = current_df['time_col']
    return current_df

# %%
current_df = meta_frame['driving']['from']['Berkeley']['to']['Mountain View']

# %%
current_df = custom_times_index(current_df)

# %%
#current_df.head()

# %% [markdown]
# ####Use new functions and create boxplot

# %%
current_df = meta_frame['driving']['from']['Russian Hill']['to']['Oakland']

# %%
current_df = custom_remove_nat(current_df)

# %%
current_df = custom_remove_wknd(current_df)
current_df
# Out:
#                            pd_id            datetime       origins  \
# 2015-04-27 03:15:00-07:00  10777 2015-04-27 10:23:20  Russian Hill
# 2015-04-27 04:00:00-07:00  10833 2015-04-27 11:00:02  Russian Hill
# 2015-04-27 04:15:00-07:00  10880 2015-04-27 11:15:02  Russian Hill
# 2015-04-27 04:30:00-07:00  10930 2015-04-27 11:30:01  Russian Hill
# 2015-04-27 04:45:00-07:00  10986 2015-04-27 11:45:01  Russian Hill
# 2015-04-27 05:00:00-07:00  11038 2015-04-27 12:00:02  Russian Hill
# 2015-04-27 05:15:00-07:00  11088 2015-04-27 12:15:02  Russian Hill
# 2015-04-27 05:30:00-07:00  11143 2015-04-27 12:30:02  Russian Hill
# 2015-04-27 05:45:00-07:00  11192 2015-04-27 12:45:02  Russian Hill
# 2015-04-27 06:00:00-07:00  11244 2015-04-27 13:00:01  Russian Hill
# 2015-04-27 06:15:00-07:00  11297 2015-04-27 13:15:02  Russian Hill
# 2015-04-27 06:30:00-07:00  11346 2015-04-27 13:30:02  Russian Hill
# 2015-04-27 06:45:00-07:00  11398 2015-04-27 13:45:01  Russian Hill
# 2015-04-27 07:00:00-07:00  11450 2015-04-27 14:00:01  Russian Hill
# 2015-04-27 07:15:00-07:00  11502 2015-04-27 14:15:01  Russian Hill
# 2015-04-27 07:30:00-07:00  11565 2015-04-27 14:30:02  Russian Hill
# 2015-04-27 07:45:00-07:00  11606 2015-04-27 14:45:01  Russian Hill
# 2015-04-27 08:00:00-07:00  11660 2015-04-27 15:00:02  Russian Hill
# 2015-04-27 08:15:00-07:00  11716 2015-04-27 15:15:02  Russian Hill
# 2015-04-27 08:30:00-07:00  11762 2015-04-27 15:30:01  Russian Hill
# 2015-04-27 08:45:00-07:00  11815 2015-04-27 15:45:02  Russian Hill
# 2015-04-27 09:00:00-07:00  11875 2015-04-27 16:00:02  Russian Hill
# 2015-04-27 09:15:00-07:00  11925 2015-04-27 16:15:02  Russian Hill
# 2015-04-27 09:30:00-07:00  11970 2015-04-27 16:30:01  Russian Hill
# 2015-04-27 09:45:00-07:00  12025 2015-04-27 16:45:02  Russian Hill
# 2015-04-27 10:00:00-07:00  12074 2015-04-27 17:00:01  Russian Hill
# 2015-04-27 10:15:00-07:00  12136 2015-04-27 17:15:02  Russian Hill
# 2015-04-27 10:30:00-07:00  12178 2015-04-27 17:30:02  Russian Hill
# 2015-04-27 10:45:00-07:00  12231 2015-04-27 17:45:02  Russian Hill
# 2015-04-27 11:00:00-07:00  12288 2015-04-27 18:00:02  Russian Hill
# ...                          ...                 ...           ...
# 2015-05-14 11:00:00-07:00  63840 2015-05-14 18:00:01  Russian Hill
# 2015-05-15 04:00:00-07:00  65425 2015-05-15 11:00:02  Russian Hill
# 2015-05-15 04:15:00-07:00  65476 2015-05-15 11:15:02  Russian Hill
# 2015-05-15 04:30:00-07:00  65531 2015-05-15 11:30:02  Russian Hill
# 2015-05-15 04:45:00-07:00  65575 2015-05-15 11:45:02  Russian Hill
# 2015-05-15 05:00:00-07:00  65634 2015-05-15 12:00:02  Russian Hill
# 2015-05-15 05:15:00-07:00  65660 2015-05-15 12:15:01  Russian Hill
# 2015-05-15 05:30:00-07:00  65736 2015-05-15 12:30:02  Russian Hill
# 2015-05-15 05:45:00-07:00  65764 2015-05-15 12:45:01  Russian Hill
# 2015-05-15 06:00:00-07:00  65819 2015-05-15 13:00:02  Russian Hill
# 2015-05-15 06:15:00-07:00  65870 2015-05-15 13:15:01  Russian Hill
# 2015-05-15 06:30:00-07:00  65920 2015-05-15 13:30:01  Russian Hill
# 2015-05-15 06:45:00-07:00  65999 2015-05-15 13:45:02  Russian Hill
# 2015-05-15 07:00:00-07:00  66025 2015-05-15 14:00:01  Russian Hill
# 2015-05-15 07:15:00-07:00  66084 2015-05-15 14:15:02  Russian Hill
# 2015-05-15 07:30:00-07:00  66154 2015-05-15 14:30:02  Russian Hill
# 2015-05-15 07:45:00-07:00  66206 2015-05-15 14:45:02  Russian Hill
# 2015-05-15 08:00:00-07:00  66245 2015-05-15 15:00:02  Russian Hill
# 2015-05-15 08:15:00-07:00  66284 2015-05-15 15:15:01  Russian Hill
# 2015-05-15 08:30:00-07:00  66336 2015-05-15 15:30:01  Russian Hill
# 2015-05-15 08:45:00-07:00  66414 2015-05-15 15:45:02  Russian Hill
# 2015-05-15 09:00:00-07:00  66440 2015-05-15 16:00:01  Russian Hill
# 2015-05-15 09:15:00-07:00  66492 2015-05-15 16:15:01  Russian Hill
# 2015-05-15 09:30:00-07:00  66568 2015-05-15 16:30:02  Russian Hill
# 2015-05-15 09:45:00-07:00  66605 2015-05-15 16:45:02  Russian Hill
# 2015-05-15 10:00:00-07:00  66653 2015-05-15 17:00:02  Russian Hill
# 2015-05-15 10:15:00-07:00  66726 2015-05-15 17:15:02  Russian Hill
# 2015-05-15 10:30:00-07:00  66752 2015-05-15 17:30:01  Russian Hill
# 2015-05-15 10:45:00-07:00  66809 2015-05-15 17:45:02  Russian Hill
# 2015-05-15 11:00:00-07:00  66878 2015-05-15 18:00:02  Russian Hill
#
#                           destinations travel_mode  duration  distance  fare  \
# 2015-04-27 03:15:00-07:00      Oakland     driving      1633     19000   NaN
# 2015-04-27 04:00:00-07:00      Oakland     driving      1709     19000   NaN
# 2015-04-27 04:15:00-07:00      Oakland     driving      1706     19000   NaN
# 2015-04-27 04:30:00-07:00      Oakland     driving      1677     19000   NaN
# 2015-04-27 04:45:00-07:00      Oakland     driving      1697     19000   NaN
# 2015-04-27 05:00:00-07:00      Oakland     driving      1704     19000   NaN
# 2015-04-27 05:15:00-07:00      Oakland     driving      1708     19000   NaN
# 2015-04-27 05:30:00-07:00      Oakland     driving      1695     19000   NaN
# 2015-04-27 05:45:00-07:00      Oakland     driving      1711     19000   NaN
# 2015-04-27 06:00:00-07:00      Oakland     driving      1726     19000   NaN
# 2015-04-27 06:15:00-07:00      Oakland     driving      1740     19000   NaN
# 2015-04-27 06:30:00-07:00      Oakland     driving      1732     19000   NaN
# 2015-04-27 06:45:00-07:00      Oakland     driving      1794     19000   NaN
# 2015-04-27 07:00:00-07:00      Oakland     driving      1814     19000   NaN
# 2015-04-27 07:15:00-07:00      Oakland     driving      1824     19000   NaN
# 2015-04-27 07:30:00-07:00      Oakland     driving      1771     19000   NaN
# 2015-04-27 07:45:00-07:00      Oakland     driving      1856     19000   NaN
# 2015-04-27 08:00:00-07:00      Oakland     driving      1913     19000   NaN
# 2015-04-27 08:15:00-07:00      Oakland     driving      2009     19000   NaN
# 2015-04-27 08:30:00-07:00      Oakland     driving      2078     19000   NaN
# 2015-04-27 08:45:00-07:00      Oakland     driving      2082     19000   NaN
# 2015-04-27 09:00:00-07:00      Oakland     driving      2056     19000   NaN
# 2015-04-27 09:15:00-07:00      Oakland     driving      2025     19000   NaN
# 2015-04-27 09:30:00-07:00      Oakland     driving      2019     19000   NaN
# 2015-04-27 09:45:00-07:00      Oakland     driving      2130     19000   NaN
# 2015-04-27 10:00:00-07:00      Oakland     driving      2123     19000   NaN
# 2015-04-27 10:15:00-07:00      Oakland     driving      2087     19000   NaN
# 2015-04-27 10:30:00-07:00      Oakland     driving      2097     19000   NaN
# 2015-04-27 10:45:00-07:00      Oakland     driving      2089     19000   NaN
# 2015-04-27 11:00:00-07:00      Oakland     driving      2128     19000   NaN
# ...                                ...         ...       ...       ...   ...
# 2015-05-14 11:00:00-07:00      Oakland     driving      1955     19000   NaN
# 2015-05-15 04:00:00-07:00      Oakland     driving      1694     19000   NaN
# 2015-05-15 04:15:00-07:00      Oakland     driving      1707     19000   NaN
# 2015-05-15 04:30:00-07:00      Oakland     driving      1703     19000   NaN
# 2015-05-15 04:45:00-07:00      Oakland     driving      2175     19000   NaN
# 2015-05-15 05:00:00-07:00      Oakland     driving      1714     19000   NaN
# 2015-05-15 05:15:00-07:00      Oakland     driving      1718     19000   NaN
# 2015-05-15 05:30:00-07:00      Oakland     driving      1728     19000   NaN
# 2015-05-15 05:45:00-07:00      Oakland     driving      1758     19000   NaN
# 2015-05-15 06:00:00-07:00      Oakland     driving      1734     19000   NaN
# 2015-05-15 06:15:00-07:00      Oakland     driving      1743     19000   NaN
# 2015-05-15 06:30:00-07:00      Oakland     driving      1777     19000   NaN
# 2015-05-15 06:45:00-07:00      Oakland     driving      1786     19000   NaN
# 2015-05-15 07:00:00-07:00      Oakland     driving      1829     19000   NaN
# 2015-05-15 07:15:00-07:00      Oakland     driving      1847     19000   NaN
# 2015-05-15 07:30:00-07:00      Oakland     driving      1833     19000   NaN
# 2015-05-15 07:45:00-07:00      Oakland     driving      1915     19000   NaN
# 2015-05-15 08:00:00-07:00      Oakland     driving      2008     19000   NaN
# 2015-05-15 08:15:00-07:00      Oakland     driving      2031     19000   NaN
# 2015-05-15 08:30:00-07:00      Oakland     driving      1999     19000   NaN
# 2015-05-15 08:45:00-07:00      Oakland     driving      2019     19000   NaN
# 2015-05-15 09:00:00-07:00      Oakland     driving      1990     19000   NaN
# 2015-05-15 09:15:00-07:00      Oakland     driving      2012     19000   NaN
# 2015-05-15 09:30:00-07:00      Oakland     driving      2202     19000   NaN
# 2015-05-15 09:45:00-07:00      Oakland     driving      2117     19000   NaN
# 2015-05-15 10:00:00-07:00      Oakland     driving      2171     19000   NaN
# 2015-05-15 10:15:00-07:00      Oakland     driving      1945     19000   NaN
# 2015-05-15 10:30:00-07:00      Oakland     driving      1987     19000   NaN
# 2015-05-15 10:45:00-07:00      Oakland     driving      2002     19000   NaN
# 2015-05-15 11:00:00-07:00      Oakland     driving      1947     19000   NaN
#
#                           congestion  time_col time_str_col    date_col
# 2015-04-27 03:15:00-07:00       Mild  03:15:00        03:15  2015-04-27
# 2015-04-27 04:00:00-07:00       Mild  04:00:00        04:00  2015-04-27
# 2015-04-27 04:15:00-07:00       Mild  04:15:00        04:15  2015-04-27
# 2015-04-27 04:30:00-07:00       Mild  04:30:00        04:30  2015-04-27
# 2015-04-27 04:45:00-07:00       Mild  04:45:00        04:45  2015-04-27
# 2015-04-27 05:00:00-07:00       Mild  05:00:00        05:00  2015-04-27
# 2015-04-27 05:15:00-07:00       Mild  05:15:00        05:15  2015-04-27
# 2015-04-27 05:30:00-07:00       Mild  05:30:00        05:30  2015-04-27
# 2015-04-27 05:45:00-07:00       Mild  05:45:00        05:45  2015-04-27
# 2015-04-27 06:00:00-07:00       Mild  06:00:00        06:00  2015-04-27
# 2015-04-27 06:15:00-07:00       Mild  06:15:00        06:15  2015-04-27
# 2015-04-27 06:30:00-07:00       Mild  06:30:00        06:30  2015-04-27
# 2015-04-27 06:45:00-07:00       Mild  06:45:00        06:45  2015-04-27
# 2015-04-27 07:00:00-07:00       Mild  07:00:00        07:00  2015-04-27
# 2015-04-27 07:15:00-07:00       Mild  07:15:00        07:15  2015-04-27
# 2015-04-27 07:30:00-07:00       Mild  07:30:00        07:30  2015-04-27
# 2015-04-27 07:45:00-07:00     Medium  07:45:00        07:45  2015-04-27
# 2015-04-27 08:00:00-07:00     Medium  08:00:00        08:00  2015-04-27
# 2015-04-27 08:15:00-07:00     Medium  08:15:00        08:15  2015-04-27
# 2015-04-27 08:30:00-07:00     Medium  08:30:00        08:30  2015-04-27
# 2015-04-27 08:45:00-07:00     Medium  08:45:00        08:45  2015-04-27
# 2015-04-27 09:00:00-07:00     Medium  09:00:00        09:00  2015-04-27
# 2015-04-27 09:15:00-07:00     Medium  09:15:00        09:15  2015-04-27
# 2015-04-27 09:30:00-07:00     Medium  09:30:00        09:30  2015-04-27
# 2015-04-27 09:45:00-07:00     Medium  09:45:00        09:45  2015-04-27
# 2015-04-27 10:00:00-07:00     Medium  10:00:00        10:00  2015-04-27
# 2015-04-27 10:15:00-07:00     Medium  10:15:00        10:15  2015-04-27
# 2015-04-27 10:30:00-07:00     Medium  10:30:00        10:30  2015-04-27
# 2015-04-27 10:45:00-07:00     Medium  10:45:00        10:45  2015-04-27
# 2015-04-27 11:00:00-07:00     Medium  11:00:00        11:00  2015-04-27
# ...                              ...       ...          ...         ...
# 2015-05-14 11:00:00-07:00     Medium  11:00:00        11:00  2015-05-14
# 2015-05-15 04:00:00-07:00       Mild  04:00:00        04:00  2015-05-15
# 2015-05-15 04:15:00-07:00       Mild  04:15:00        04:15  2015-05-15
# 2015-05-15 04:30:00-07:00       Mild  04:30:00        04:30  2015-05-15
# 2015-05-15 04:45:00-07:00     Medium  04:45:00        04:45  2015-05-15
# 2015-05-15 05:00:00-07:00       Mild  05:00:00        05:00  2015-05-15
# 2015-05-15 05:15:00-07:00       Mild  05:15:00        05:15  2015-05-15
# 2015-05-15 05:30:00-07:00       Mild  05:30:00        05:30  2015-05-15
# 2015-05-15 05:45:00-07:00       Mild  05:45:00        05:45  2015-05-15
# 2015-05-15 06:00:00-07:00       Mild  06:00:00        06:00  2015-05-15
# 2015-05-15 06:15:00-07:00       Mild  06:15:00        06:15  2015-05-15
# 2015-05-15 06:30:00-07:00       Mild  06:30:00        06:30  2015-05-15
# 2015-05-15 06:45:00-07:00       Mild  06:45:00        06:45  2015-05-15
# 2015-05-15 07:00:00-07:00       Mild  07:00:00        07:00  2015-05-15
# 2015-05-15 07:15:00-07:00       Mild  07:15:00        07:15  2015-05-15
# 2015-05-15 07:30:00-07:00       Mild  07:30:00        07:30  2015-05-15
# 2015-05-15 07:45:00-07:00     Medium  07:45:00        07:45  2015-05-15
# 2015-05-15 08:00:00-07:00     Medium  08:00:00        08:00  2015-05-15
# 2015-05-15 08:15:00-07:00     Medium  08:15:00        08:15  2015-05-15
# 2015-05-15 08:30:00-07:00     Medium  08:30:00        08:30  2015-05-15
# 2015-05-15 08:45:00-07:00     Medium  08:45:00        08:45  2015-05-15
# 2015-05-15 09:00:00-07:00     Medium  09:00:00        09:00  2015-05-15
# 2015-05-15 09:15:00-07:00     Medium  09:15:00        09:15  2015-05-15
# 2015-05-15 09:30:00-07:00     Medium  09:30:00        09:30  2015-05-15
# 2015-05-15 09:45:00-07:00     Medium  09:45:00        09:45  2015-05-15
# 2015-05-15 10:00:00-07:00     Medium  10:00:00        10:00  2015-05-15
# 2015-05-15 10:15:00-07:00     Medium  10:15:00        10:15  2015-05-15
# 2015-05-15 10:30:00-07:00     Medium  10:30:00        10:30  2015-05-15
# 2015-05-15 10:45:00-07:00     Medium  10:45:00        10:45  2015-05-15
# 2015-05-15 11:00:00-07:00     Medium  11:00:00        11:00  2015-05-15
#
# [457 rows x 12 columns]

# %%
current_df.ix['4/27/2015':'5/16/2015',['duration']].plot(figsize=(16,10))

# %%
current_df = current_df[(current_df.index.hour >= 4) & (current_df.index.hour <=11)]

# %%
current_df.ix[:,['duration','time_str_col']].boxplot(by='time_str_col',rot=50,figsize=(14,8))

# %%
#examine the morning drive from russian hill to oakland (between dates of 5/04 and 5/11

# %%
#need to figure out how to manipulate multiple days worth of data (combine the hours)
#explore possibility of using groupby (seen on pg316)

# %%
current_df = current_df[(current_df.index.hour >= 4) & (current_df.index.hour <=11)]

# %%
minutes = []
for each_time in current_df['time_col']:
    hour = each_time.hour
    minute = each_time.minute
    minute = minute + (60 * hour)
    minutes.append(minute)
seconds = []
for each_time in current_df['time_col']:
    this_hour = each_time.hour
    this_minute = each_time.minute
    this_seconds = (3600*this_hour) + (60*this_minute)
    seconds.append(this_seconds)

# %%
#print minutes
current_df['minutes_col'] = minutes
current_df['seconds_col'] = seconds

# %%
#current_df

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.cross_validation import train_test_split

# %%
#implement train/test/split
x = current_df['seconds_col'].values
y = current_df['duration'].values
x_train, x_test, y_train, y_test = train_test_split(x[:,np.newaxis],y, test_size = .33, random_state = 3)

# %%
model = Pipeline([('poly', PolynomialFeatures(degree=3)), ('linear', LinearRegression(fit_intercept=False))])
# fit to an order-3 polynomial data
###model = LinearRegression()
model = model.fit(x_train,y_train)
#model.named_steps['linear'].coef_
###model.coef_

# %%
predicted = model.predict(x_test)
predicted = predicted.astype(np.int64)
y_test = y_test.astype(np.int64)
print predicted; print y_test
# Out:
# [1839 2031 2073 1792 2053 1769 2031 1733 1772 1755 1749 1749 2077 1769 1755
#  1755 2036 1970 1772 1729 1970 1918 1755 1945 1839 1742 2077 1891 2031 2077
#  2077 2073 1918 1970 2052 2075 1769 2031 2065 1918 1918 1792 1772 1736 1865
#  1891 1772 2052 2052 2036 1945 2002 2065 1772 2016 1994 1815 2016 1792 1769
#  1742 1918 1733 1749 2067 1815 1772 2036 1815 2031 2016 1772 2075 2031 1736
#  1749 2053 1865 1772 2067 1772 1815 1865 2077 2075 1815 2075 1733 1736 1729
#  1865 1945 2053 1742 2067 2052 2016 1749 2053 1865 2052 1839 1891 1729 2016
#  1755 2031 1729 2073 1994 2052 2053 1945 1815 1918 2031 2075 2077 2075 1865
#  2053 1891 1769 2073 1839 1815 1815 2067 2065 1970 2002 2075 1865 2077 2036
#  1749 1945 2065 1792 1945 1733 1994 2016 1994]
# [1897 2089 2071 1714 1963 1690 1998 1707 1726 1707 1726 1739 1998 1725 1660
#  1722 2019 1913 1745 1831 1923 1771 1729 1856 1754 1700 2155 1834 2039 2076
#  2055 2192 1822 2049 2003 2104 1720 1995 2018 1883 1768 1787 1734 1714 1806
#  1814 1730 1990 2224 2007 1978 1989 2015 1786 1983 1914 1751 1999 1745 2214
#  1890 1889 1715 1784 2310 1707 1753 2193 1880 1967 2158 1714 2123 2047 1698
#  1726 2016 1802 1734 2141 1745 1753 1850 1981 1999 1777 2290 1636 1705 1697
#  1804 1913 1987 1728 1863 2193 2193 1685 1972 1819 1968 1775 1842 1721 1987
#  1744 1997 1711 1945 2119 2062 1871 1950 1757 1895 2168 2156 1989 1989 1791
#  2202 1798 1724 2135 1867 1732 1739 2188 2012 1893 2005 2171 1908 2130 2155
#  1698 1918 2203 1736 1929 1708 1918 2016 1986]

# %%
accuracy_score(y_test, predicted)
# Out:
# 0.0069444444444444441

# %%
x = current_df[(current_df.index.hour >= 4) & (current_df.index.hour <=11)].index.values
y = current_df[(current_df.index.hour >= 4) & (current_df.index.hour <=11)]['duration']

# %%
clf.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-781-5c1831092d7a> in <module>()
# ----> 1 clf.fit(x,y)
#
# /Users/gpnaifeh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in fit(self, X, y, n_jobs)
#     353
#     354         X, y, X_mean, y_mean, X_std = self._center_data(
# --> 355             X, y, self.fit_intercept, self.normalize, self.copy_X)
#     356
#     357         if sp.issparse(X):
#
# /Users/gpnaifeh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in center_data(X, y, fit_intercept, normalize, copy, sample_weight)
#     102                 X /= X_std
#     103             else:
# --> 104                 X_std = np.ones(X.shape[1])
#     105         y_mean = np.average(y, axis=0, weights=sample_weight)
#     106         y = y - y_mean
#
# IndexError: tuple index out of range

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.tsa as tsa

# %%
x = current_df[(current_df.index.hour >= 4) & (current_df.index.hour <=11)].index.values
y = current_df[(current_df.index.hour >= 4) & (current_df.index.hour <=11)]['duration'].values

# %%
results = tsa.ar_model.AR(current_df['duration'])

# %%
results.fit()

# %%
tsa.ar_model.ARResults(results,(y,x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-883-caacf0af3519> in <module>()
# ----> 1 tsa.ar_model.ARResults(results,(y,x)).summary()
#
# AttributeError: 'ARResults' object has no attribute 'summary'

# %%
arma_mod = sm.tsa.ARMA(current_df[(current_df.index.hour >= 4) & (current_df.index.hour <=11)]['duration'], order=(2,2))
arma_res = arma_mod.fit(trend='nc', disp=-1)
print tsa.arima_model.ARMA.score(arma_mod,current_df[(current_df.index.hour >= 4) & (current_df.index.hour <=11)]['duration'])
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-926-4ee7ea373f66> in <module>()
#       1 arma_mod = sm.tsa.ARMA(current_df[(current_df.index.hour >= 4) & (current_df.index.hour <=11)]['duration'], order=(2,2))
#       2 arma_res = arma_mod.fit(trend='nc', disp=-1)
# ----> 3 print tsa.arima_model.ARMA.score(arma_mod,current_df[(current_df.index.hour >= 4) & (current_df.index.hour <=11)]['duration'])
#
# /Users/gpnaifeh/anaconda/lib/python2.7/site-packages/statsmodels/tsa/arima_model.pyc in score(self, params)
#     573         This is a numerical approximation.
#     574         """
# --> 575         return approx_fprime_cs(params, self.loglike, args=(False,))
#     576
#     577     def hessian(self, params):
#
# /Users/gpnaifeh/anaconda/lib/python2.7/site-packages/statsmodels/tools/numdiff.pyc in approx_fprime_cs(x, f, epsilon, args, kwargs)
#     182     n = len(x)
#     183     epsilon = _get_epsilon(x, 1, epsilon, n)
# --> 184     increments = np.identity(n) * 1j * epsilon
#     185     #TODO: see if this can be vectorized, but usually dim is small
#     186     partials = [f(x+ih, *args, **kwargs).imag / epsilon[i]
#
# /Users/gpnaifeh/anaconda/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name)
#     531             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     532                                      index=left.index, name=left.name,
# --> 533                                      dtype=dtype)
#     534     return wrapper
#     535
#
# /Users/gpnaifeh/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __init__(self, data, index, dtype, name, copy, fastpath)
#     209             else:
#     210                 data = _sanitize_array(data, index, dtype, copy,
# --> 211                                        raise_cast_failure=True)
#     212
#     213                 data = SingleBlockManager(data, index, fastpath=True)
#
# /Users/gpnaifeh/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    2683     elif subarr.ndim > 1:
#    2684         if isinstance(data, np.ndarray):
# -> 2685             raise Exception('Data must be 1-dimensional')
#    2686         else:
#    2687             subarr = _asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional

# %%
#write to csv
#df.to_csv('foo.csv')
#read from csv
#pd.read_csv('foo.csv')
'''
normalizaiton
regularization
regression
auto regression
arma
statsmodels
time series
'''
