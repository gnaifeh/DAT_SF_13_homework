# %% [markdown]
# # Final Project: Phase 3: Manipulating Maps Data with Pandas

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import MySQLdb as mdb
import MySQL_data_file as MySQL_data

# %%
con = mdb.connect(MySQL_data.my_sql_host, MySQL_data.my_sql_user,\
                    MySQL_data.my_sql_passwd,\
                    MySQL_data.my_sql_database)
#con.close

# %%
def run_sql(query):
    cur = con.cursor()
    cur.execute(query)
    con.commit()
    #con.close()
    return cur.fetchall()

# %% [markdown]
# ####Read in the data from SQL and combine into a single DataFrame

# %%
gmaps_df = pd.read_sql("""SELECT entry_id,timestamp,datetime,origins,destinations,travel_mode,duration,distance,fare
                        FROM gmaps_data""",con)
bing_df = pd.read_sql("""SELECT entry_id,timestamp,datetime,origins,destinations,travel_mode,duration_traffic,distance,congestion
                        FROM mmaps_data""",con)
#changing the bing maps "duration_traffic" column to "duration" in order to match up the column with the gmaps_df
bing_df.columns = [u'entry_id', u'timestamp', u'datetime', u'origins', u'destinations', u'travel_mode', u'duration', u'distance', u'congestion']
combined_df = gmaps_df.merge(bing_df, how='outer')
combined_df = combined_df.copy()
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58432 entries, 0 to 58431
# Data columns (total 10 columns):
# entry_id        58432 non-null float64
# timestamp       58432 non-null datetime64[ns]
# datetime        58432 non-null datetime64[ns]
# origins         58432 non-null object
# destinations    58432 non-null object
# travel_mode     58432 non-null object
# duration        58248 non-null float64
# distance        58248 non-null float64
# fare            19981 non-null float64
# congestion      23942 non-null object
# dtypes: datetime64[ns](2), float64(4), object(4)
# memory usage: 4.9+ MB
#        entry_id           timestamp            datetime      origins  \
# 1             1 2015-04-27 02:32:58 2015-04-27 09:32:56  Oakland, CA
# 3             2 2015-04-27 02:32:58 2015-04-27 09:32:56  Oakland, CA
# 5             3 2015-04-27 02:32:58 2015-04-27 09:32:56  Oakland, CA
# 7             4 2015-04-27 02:32:59 2015-04-27 09:32:56  Oakland, CA
# 9             5 2015-04-27 02:32:59 2015-04-27 09:32:56  Oakland, CA
# 11            6 2015-04-27 02:32:59 2015-04-27 09:32:57  Oakland, CA
# 71           36 2015-04-27 02:33:07 2015-04-27 09:33:07  Oakland, CA
# 73           37 2015-04-27 02:33:07 2015-04-27 09:33:07  Oakland, CA
# 111          56 2015-04-27 02:59:05 2015-04-27 09:59:04  Oakland, CA
# 113          57 2015-04-27 02:59:05 2015-04-27 09:59:04  Oakland, CA
# 151          76 2015-04-27 02:59:05 2015-04-27 09:59:05  Oakland, CA
# 153          77 2015-04-27 02:59:05 2015-04-27 09:59:05  Oakland, CA
# 161          81 2015-04-27 03:05:04 2015-04-27 10:05:02  Oakland, CA
# 163          82 2015-04-27 03:05:04 2015-04-27 10:05:02  Oakland, CA
# 165          83 2015-04-27 03:05:04 2015-04-27 10:05:02  Oakland, CA
# 167          84 2015-04-27 03:05:04 2015-04-27 10:05:02  Oakland, CA
# 169          85 2015-04-27 03:05:04 2015-04-27 10:05:02  Oakland, CA
# 171          86 2015-04-27 03:05:04 2015-04-27 10:05:02  Oakland, CA
# 243         122 2015-04-27 03:23:24 2015-04-27 10:23:24  Oakland, CA
# 245         123 2015-04-27 03:23:25 2015-04-27 10:23:24  Oakland, CA
# 253         127 2015-04-27 03:24:21 2015-04-27 10:24:17  Oakland, CA
# 255         128 2015-04-27 03:24:21 2015-04-27 10:24:17  Oakland, CA
# 257         129 2015-04-27 03:24:21 2015-04-27 10:24:18  Oakland, CA
# 259         130 2015-04-27 03:24:21 2015-04-27 10:24:18  Oakland, CA
# 261         131 2015-04-27 03:24:21 2015-04-27 10:24:18  Oakland, CA
# 263         132 2015-04-27 03:24:21 2015-04-27 10:24:18  Oakland, CA
# 265         133 2015-04-27 03:24:21 2015-04-27 10:24:18  Oakland, CA
# 267         134 2015-04-27 03:24:21 2015-04-27 10:24:18  Oakland, CA
# 347         174 2015-04-27 04:00:06 2015-04-27 11:00:05  Oakland, CA
# 349         175 2015-04-27 04:00:06 2015-04-27 11:00:06  Oakland, CA
# ...         ...                 ...                 ...          ...
# 47681     23841 2015-05-12 15:45:08 2015-05-12 22:45:02  Oakland, CA
# 47683     23842 2015-05-12 15:45:08 2015-05-12 22:45:02  Oakland, CA
# 47685     23843 2015-05-12 15:45:08 2015-05-12 22:45:03  Oakland, CA
# 47687     23844 2015-05-12 15:45:08 2015-05-12 22:45:04  Oakland, CA
# 47689     23845 2015-05-12 15:45:08 2015-05-12 22:45:04  Oakland, CA
# 47691     23846 2015-05-12 15:45:08 2015-05-12 22:45:04  Oakland, CA
# 47729     23865 2015-05-12 16:00:06 2015-05-12 23:00:01  Oakland, CA
# 47731     23866 2015-05-12 16:00:06 2015-05-12 23:00:02  Oakland, CA
# 47733     23867 2015-05-12 16:00:06 2015-05-12 23:00:02  Oakland, CA
# 47735     23868 2015-05-12 16:00:06 2015-05-12 23:00:02  Oakland, CA
# 47737     23869 2015-05-12 16:00:06 2015-05-12 23:00:02  Oakland, CA
# 47739     23870 2015-05-12 16:00:06 2015-05-12 23:00:02  Oakland, CA
# 47741     23871 2015-05-12 16:00:06 2015-05-12 23:00:02  Oakland, CA
# 47743     23872 2015-05-12 16:00:06 2015-05-12 23:00:03  Oakland, CA
# 47781     23891 2015-05-12 16:15:06 2015-05-12 23:15:01  Oakland, CA
# 47783     23892 2015-05-12 16:15:06 2015-05-12 23:15:01  Oakland, CA
# 47785     23893 2015-05-12 16:15:06 2015-05-12 23:15:02  Oakland, CA
# 47787     23894 2015-05-12 16:15:06 2015-05-12 23:15:02  Oakland, CA
# 47789     23895 2015-05-12 16:15:06 2015-05-12 23:15:02  Oakland, CA
# 47791     23896 2015-05-12 16:15:06 2015-05-12 23:15:02  Oakland, CA
# 47793     23897 2015-05-12 16:15:06 2015-05-12 23:15:02  Oakland, CA
# 47795     23898 2015-05-12 16:15:06 2015-05-12 23:15:02  Oakland, CA
# 47833     23917 2015-05-12 16:30:08 2015-05-12 23:30:02  Oakland, CA
# 47835     23918 2015-05-12 16:30:08 2015-05-12 23:30:02  Oakland, CA
# 47837     23919 2015-05-12 16:30:08 2015-05-12 23:30:02  Oakland, CA
# 47839     23920 2015-05-12 16:30:08 2015-05-12 23:30:03  Oakland, CA
# 47841     23921 2015-05-12 16:30:08 2015-05-12 23:30:03  Oakland, CA
# 47843     23922 2015-05-12 16:30:08 2015-05-12 23:30:03  Oakland, CA
# 47845     23923 2015-05-12 16:30:08 2015-05-12 23:30:03  Oakland, CA
# 47847     23924 2015-05-12 16:30:08 2015-05-12 23:30:03  Oakland, CA
#
#                                 destinations travel_mode  duration  distance  \
# 1         Pacific Heights, San Francisco, CA     driving      1750        23
# 3          Outer Richmond, San+Francisco, CA     driving      2089        27
# 5            Outer Sunset, San Francisco, CA     driving      2097        36
# 7        Mission District, San Francisco, CA     driving      1397        20
# 9              Noe Valley, San+Francisco, CA     driving      1576        24
# 11                              Berkeley, CA     driving       856        12
# 71     Financial District, San Francisco, CA     driving      1175        18
# 73                         Mountain View, CA     driving      2830        65
# 111    Financial District, San Francisco, CA     driving      1178        18
# 113                        Mountain View, CA     driving      2813        65
# 151    Financial District, San Francisco, CA     driving      1178        18
# 153                        Mountain View, CA     driving      2813        65
# 161       Pacific Heights, San Francisco, CA     driving      1773        23
# 163        Outer Richmond, San+Francisco, CA     driving      2113        27
# 165          Outer Sunset, San Francisco, CA     driving      2114        36
# 167      Mission District, San Francisco, CA     driving      1412        20
# 169            Noe Valley, San+Francisco, CA     driving      1596        24
# 171                             Berkeley, CA     driving       867        12
# 243    Financial District, San Francisco, CA     driving      1168        18
# 245                        Mountain View, CA     driving      2852        65
# 253          Russian Hill, San Francisco, CA     driving      1657        20
# 255           North Beach, San Francisco, CA     driving      1417        20
# 257       Pacific Heights, San Francisco, CA     driving      1756        23
# 259        Outer Richmond, San+Francisco, CA     driving      2093        27
# 261          Outer Sunset, San Francisco, CA     driving      2067        36
# 263      Mission District, San Francisco, CA     driving      1382        20
# 265            Noe Valley, San+Francisco, CA     driving      1533        24
# 267                             Berkeley, CA     driving       842        12
# 347    Financial District, San Francisco, CA     driving      1175        18
# 349                        Mountain View, CA     driving      2855        65
# ...                                      ...         ...       ...       ...
# 47681     Pacific Heights, San Francisco, CA     driving      2110        23
# 47683      Outer Richmond, San+Francisco, CA     driving      2496        27
# 47685        Outer Sunset, San Francisco, CA     driving      2498        36
# 47687    Mission District, San Francisco, CA     driving      1569        20
# 47689          Noe Valley, San+Francisco, CA     driving      1880        24
# 47691                           Berkeley, CA     driving      1115         9
# 47729        Russian Hill, San Francisco, CA     driving      1935        20
# 47731         North Beach, San Francisco, CA     driving      1791        20
# 47733     Pacific Heights, San Francisco, CA     driving      2180        23
# 47735      Outer Richmond, San+Francisco, CA     driving      2578        27
# 47737        Outer Sunset, San Francisco, CA     driving      2557        36
# 47739    Mission District, San Francisco, CA     driving      1574        20
# 47741          Noe Valley, San+Francisco, CA     driving      1935        24
# 47743                           Berkeley, CA     driving      1132         9
# 47781        Russian Hill, San Francisco, CA     driving      1943        20
# 47783         North Beach, San Francisco, CA     driving      1811        20
# 47785     Pacific Heights, San Francisco, CA     driving      2192        23
# 47787      Outer Richmond, San+Francisco, CA     driving      2596        27
# 47789        Outer Sunset, San Francisco, CA     driving      2590        36
# 47791    Mission District, San Francisco, CA     driving      1603        20
# 47793          Noe Valley, San+Francisco, CA     driving      1947        24
# 47795                           Berkeley, CA     driving      1160         9
# 47833        Russian Hill, San Francisco, CA     driving      1907        20
# 47835         North Beach, San Francisco, CA     driving      1799        20
# 47837     Pacific Heights, San Francisco, CA     driving      2260        23
# 47839      Outer Richmond, San+Francisco, CA     driving      2676        27
# 47841        Outer Sunset, San Francisco, CA     driving      2669        36
# 47843    Mission District, San Francisco, CA     driving      1718        20
# 47845          Noe Valley, San+Francisco, CA     driving      2059        24
# 47847                           Berkeley, CA     driving      1147         9
#
#        fare congestion
# 1       NaN       None
# 3       NaN       None
# 5       NaN       None
# 7       NaN       Mild
# 9       NaN       None
# 11      NaN       None
# 71      NaN       None
# 73      NaN       None
# 111     NaN       None
# 113     NaN       None
# 151     NaN       None
# 153     NaN       None
# 161     NaN       Mild
# 163     NaN       None
# 165     NaN       None
# 167     NaN       Mild
# 169     NaN       None
# 171     NaN       None
# 243     NaN       None
# 245     NaN       None
# 253     NaN       Mild
# 255     NaN       None
# 257     NaN       Mild
# 259     NaN       None
# 261     NaN       None
# 263     NaN       None
# 265     NaN       None
# 267     NaN       None
# 347     NaN       None
# 349     NaN       None
# ...     ...        ...
# 47681   NaN     Medium
# 47683   NaN     Medium
# 47685   NaN     Medium
# 47687   NaN       Mild
# 47689   NaN     Medium
# 47691   NaN     Medium
# 47729   NaN     Medium
# 47731   NaN     Medium
# 47733   NaN     Medium
# 47735   NaN     Medium
# 47737   NaN     Medium
# 47739   NaN     Medium
# 47741   NaN     Medium
# 47743   NaN     Medium
# 47781   NaN     Medium
# 47783   NaN     Medium
# 47785   NaN     Medium
# 47787   NaN     Medium
# 47789   NaN     Medium
# 47791   NaN     Medium
# 47793   NaN     Medium
# 47795   NaN     Medium
# 47833   NaN     Medium
# 47835   NaN     Medium
# 47837   NaN     Medium
# 47839   NaN     Medium
# 47841   NaN     Medium
# 47843   NaN     Medium
# 47845   NaN     Medium
# 47847   NaN     Medium
#
# [4432 rows x 10 columns]

# %% [markdown]
# ####Remove all rows in the combined DataFrame where duration is Null

# %% [markdown]
# Note: It appears that all data between April 22 and 25 was corrupted. Should delete or remove any references

# %%
#can also use sql to look for null values: select * from gmaps_data where duration is NULL
combined_df = combined_df.ix[pd.notnull(combined_df['duration']),:].sort(columns='entry_id', ascending='True').copy()

# %%
print len(combined_df[pd.isnull(combined_df['duration'])])
print len(combined_df[pd.notnull(combined_df['duration'])])
#combined_df.info()
# Out:
# 0
# 58248

# %%
combined_df.head()
# Out:
#    entry_id           timestamp            datetime  \
# 0         1 2015-04-20 01:14:42 2015-04-20 08:14:42
# 1         1 2015-04-27 02:32:58 2015-04-27 09:32:56
# 2         2 2015-04-20 01:14:42 2015-04-20 08:14:42
# 3         2 2015-04-27 02:32:58 2015-04-27 09:32:56
# 4         3 2015-04-20 01:14:42 2015-04-20 08:14:42
#
#                                 origins  \
# 0  Outer Sunset, San Francisco, CA, USA
# 1                           Oakland, CA
# 2  Outer Sunset, San Francisco, CA, USA
# 3                           Oakland, CA
# 4    Noe Valley, San Francisco, CA, USA
#
#                                  destinations travel_mode  duration  distance  \
# 0  Financial District, San Francisco, CA, USA     transit      2661     11969
# 1          Pacific Heights, San Francisco, CA     driving      1750        23
# 2                            Oakland, CA, USA     transit      6056     30158
# 3           Outer Richmond, San+Francisco, CA     driving      2089        27
# 4  Financial District, San Francisco, CA, USA     transit      3182      9355
#
#    fare congestion
# 0     2        NaN
# 1   NaN       None
# 2   NaN        NaN
# 3   NaN       None
# 4     2        NaN

# %% [markdown]
# ####The code below separates out all rows where the origin and destination are Oakland. This only applies to gmaps data.

# %%
#Using ~ to select opposite
#print len(combined_df)
#print len(combined_df[((combined_df['origins'] =='Oakland, CA, USA')\
#                        & (combined_df['destinations'] == 'Oakland, CA, USA'))])
'''
print len(combined_df[~((combined_df['origins'] =='Oakland, CA, USA')\
                        & (combined_df['destinations'] == 'Oakland, CA, USA'))])
#Below code produces the same as the previous selection
print len(combined_df[((combined_df['origins'] !='Oakland, CA, USA')\
                          | (combined_df['destinations'] != 'Oakland, CA, USA'))])
'''
#The below code gets rid of all rows where the duration value is 0 (e.g. Oakland to Oakland trips)
combined_df2 = combined_df[combined_df['distance'] != 0].copy()
#print len(combined_df2)
#combined_df2.head()

# %% [markdown]
# ####Normalizing origin/destination names by replacing with shorter names

# %%
combined_df3 = combined_df2.copy()

# %%
#The following code displays/stores the distinct names in the origins and destinations
origins_sorted = np.sort(pd.Series.unique(combined_df3['origins']))
destinations_sorted = np.sort(pd.Series.unique(combined_df3['destinations']))
#for value in origins_sorted: print value
#for value in destinations_sorted: print value

# %%
#this is the list of names that will be replacing longer names for origins/destinations
new_names = ['Oakland','Berkeley', 'Financial District', 'Mission',\
             'Mountain View', 'Noe Valley', 'North Beach', 'Russian Hill',\
             'Pacific Heights', 'Outer Sunset', 'Outer Richmond']

# %%
#the following code normalizes the district and city names in the origin and destination columns,
#replaces longer names with shorter names from list above
for short_name in new_names:
    combined_df3.ix[combined_df3['origins'].str.contains(short_name), 'origins'] = short_name
    combined_df3.ix[combined_df3['destinations'].str.contains(short_name), 'destinations'] = short_name

# %%
#check to make sure that name normalization was successful
#combined_df3.head()
#print np.sort(pd.Series.unique(combined_df3['origins']))
#print np.sort(pd.Series.unique(combined_df3['destinations']))
##################################
#making sure that there were no incidents in updating the origins and destinations
#by looking to see if any origin/destination pairs are equivalent
len(combined_df3[combined_df3['origins'] != combined_df3['destinations']])
# Out:
# 57750

# %% [markdown]
# ####Let's focus now on what is most important: duration (or travel time between origin and destination)

# %%
combined_df3.ix[:,0:7].head() #focusing data in on the duration value (let's forget about distance, etc.)
# Out:
#    entry_id           timestamp            datetime       origins  \
# 0         1 2015-04-20 01:14:42 2015-04-20 08:14:42  Outer Sunset
# 1         1 2015-04-27 02:32:58 2015-04-27 09:32:56       Oakland
# 2         2 2015-04-20 01:14:42 2015-04-20 08:14:42  Outer Sunset
# 3         2 2015-04-27 02:32:58 2015-04-27 09:32:56       Oakland
# 4         3 2015-04-20 01:14:42 2015-04-20 08:14:42    Noe Valley
#
#          destinations travel_mode  duration
# 0  Financial District     transit      2661
# 1     Pacific Heights     driving      1750
# 2             Oakland     transit      6056
# 3      Outer Richmond     driving      2089
# 4  Financial District     transit      3182

# %% [markdown]
# ####Quick aside: practice saving the data in a csv file and reading it back into a dataframe)

# %%
combined_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57750 entries, 0 to 58431
# Data columns (total 10 columns):
# entry_id        57750 non-null float64
# timestamp       57750 non-null datetime64[ns]
# datetime        57750 non-null datetime64[ns]
# origins         57750 non-null object
# destinations    57750 non-null object
# travel_mode     57750 non-null object
# duration        57750 non-null float64
# distance        57750 non-null float64
# fare            19981 non-null float64
# congestion      23942 non-null object
# dtypes: datetime64[ns](2), float64(4), object(4)
# memory usage: 4.8+ MB

# %%
#combined_df3.to_csv('maps_may12_afternoon.csv')
combined_df4 = pd.read_csv('maps_may12_afternoon.csv')
combined_df4.columns = [u'pandas_id',u'entry_id', u'timestamp', u'datetime', u'origins', u'destinations', u'travel_mode', u'duration', u'distance', u'fare', u'congestion']
combined_df4.drop(['entry_id','timestamp'], axis=1, inplace=True) #drop redundant entry_id's from MYSQL and replace with distinct pandas_id's

# %% [markdown]
# ####Note: when reading in from csv, need to re-assign the timestamp and datetime columns as datetime objects

# %%
from datetime import datetime
from datetime import timedelta

# %%
#two ways to do this...can use "df.astype(dtype)" or "pd.to_datetime". The issue with using the 
#pandas "pd.to_datetime" is that it only applies to a series or list-like object
####################################################################
#combined_df4.loc[:,['timestamp', 'datetime']] = combined_df4[['timestamp', 'datetime']].astype('datetime64[ns]')
#combined_df4['timestamp'] = combined_df4['timestamp'].astype('datetime64[ns]')
#combined_df4['timestamp'] = pd.to_datetime(combined_df4['timestamp'])
#pd.to_datetime((combined_df4.loc[:,['datetime']].values))
#timestamp_values = combined_df4['timestamp'].values
datetime_values = combined_df4['datetime'].values
#combined_df4.loc[:,['timestamp']] = pd.to_datetime(timestamp_values)
combined_df4.loc[:,['datetime']] = pd.to_datetime(datetime_values)
combined_df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57750 entries, 0 to 57749
# Data columns (total 9 columns):
# pandas_id       57750 non-null int64
# datetime        57750 non-null datetime64[ns]
# origins         57750 non-null object
# destinations    57750 non-null object
# travel_mode     57750 non-null object
# duration        57750 non-null float64
# distance        57750 non-null float64
# fare            19981 non-null float64
# congestion      23942 non-null object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 4.4+ MB

# %% [markdown]
# ####Now let's work to separate out weekends from the data (perhaps create a separate dataframe for weekends/weekdays)

# %% [markdown]
# Create dataframe containing only duration information for each route.

# %%
duration_df = combined_df4.iloc[:,:7].copy()
#duration_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57750 entries, 0 to 57749
# Data columns (total 7 columns):
# pandas_id       57750 non-null int64
# datetime        57750 non-null datetime64[ns]
# origins         57750 non-null object
# destinations    57750 non-null object
# travel_mode     57750 non-null object
# duration        57750 non-null float64
# distance        57750 non-null float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 3.5+ MB

# %%
data_datetime_range = duration_df.datetime
column_names = duration_df.columns
# Out:
#                     pandas_id             datetime       origins  \
# datetime
# 2015-04-20 08:14:42         0  2015-04-20 08:14:42  Outer Sunset
# 2015-04-27 09:32:56         1  2015-04-27 09:32:56       Oakland
# 2015-04-20 08:14:42         2  2015-04-20 08:14:42  Outer Sunset
# 2015-04-27 09:32:56         3  2015-04-27 09:32:56       Oakland
# 2015-04-20 08:14:42         4  2015-04-20 08:14:42    Noe Valley
#
#                            destinations travel_mode duration distance
# datetime
# 2015-04-20 08:14:42  Financial District     transit     2661    11969
# 2015-04-27 09:32:56     Pacific Heights     driving     1750       23
# 2015-04-20 08:14:42             Oakland     transit     6056    30158
# 2015-04-27 09:32:56      Outer Richmond     driving     2089       27
# 2015-04-20 08:14:42  Financial District     transit     3182     9355

# %%
df_ts1 = pd.DataFrame(duration_df2.values, index=data_datetime_range, columns=column_names)
df_ts1.head()

# %%
df_ts1.index = df_ts1.index.tz_localize('UTC')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-784-4a578b48e58e> in <module>()
# ----> 1 df_ts1.index = df_ts1.index.tz_localize('UTC')
#
# /Users/gpnaifeh/anaconda/lib/python2.7/site-packages/pandas/util/decorators.pyc in wrapper(*args, **kwargs)
#      86                 else:
#      87                     kwargs[new_arg_name] = new_arg_value
# ---> 88             return func(*args, **kwargs)
#      89         return wrapper
#      90     return _deprecate_kwarg
#
# /Users/gpnaifeh/anaconda/lib/python2.7/site-packages/pandas/tseries/index.pyc in tz_localize(self, tz, ambiguous)
#    1643                 new_dates = tslib.tz_convert(self.asi8, 'UTC', self.tz)
#    1644             else:
# -> 1645                 raise TypeError("Already tz-aware, use tz_convert to convert.")
#    1646         else:
#    1647             tz = tslib.maybe_get_tz(tz)
#
# TypeError: Already tz-aware, use tz_convert to convert.

# %%
df_ts1.index = df_ts1.index.tz_convert('US/Pacific')

# %%
df_ts1.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2015-04-20 01:14:42-07:00, ..., 2015-05-12 16:30:08-07:00]
# Length: 57750, Freq: None, Timezone: US/Pacific

# %%
df_ts1.sort_index(axis=0, ascending=True, inplace=True)
df_ts1.sort(columns=['datetime','origins','destinations','travel_mode'], inplace=True)

# %% [markdown]
# ####must separate out into each origin/destination pair before resampling

# %%
#examine the morning drive from russian hill to oakland (between dates of 5/04 and 5/11

# %%
morn_drive_r_o = df_ts1[(df_ts1['travel_mode'] == 'driving') &\
                                           (df_ts1['origins']=='Russian Hill') &\
                                           (df_ts1['destinations']=='Oakland')].ix['5/04/2015':'5/11/2015',2:6].copy()

# %%
morn_drive_r_o.head()
# Out:
#                                 origins destinations travel_mode duration
# datetime
# 2015-05-04 04:00:02-07:00  Russian Hill      Oakland     driving     1702
# 2015-05-04 04:15:02-07:00  Russian Hill      Oakland     driving     1726
# 2015-05-04 04:30:01-07:00  Russian Hill      Oakland     driving     1724
# 2015-05-04 04:45:02-07:00  Russian Hill      Oakland     driving     1716
# 2015-05-04 05:00:01-07:00  Russian Hill      Oakland     driving     1703

# %%
#downsampling the data to 15 min intervals
morn_drive_r_o = morn_drive_r_o.resample('15min',how='first',closed='left', label='left') #pg 315 of data analysis for python
morn_drive_r_o.head()
# Out:
#                                 origins destinations travel_mode  duration
# datetime
# 2015-05-04 04:00:00-07:00  Russian Hill      Oakland     driving      1702
# 2015-05-04 04:15:00-07:00  Russian Hill      Oakland     driving      1726
# 2015-05-04 04:30:00-07:00  Russian Hill      Oakland     driving      1724
# 2015-05-04 04:45:00-07:00  Russian Hill      Oakland     driving      1716
# 2015-05-04 05:00:00-07:00  Russian Hill      Oakland     driving      1703

# %%
#need to figure out how to manipulate multiple days worth of data (combine the hours)
#explore possibility of using groupby (seen on pg316)

# %%
morn_drive_r_o['5/05/2015':'5/06/2015'].plot()

# %%
#write to csv
#df.to_csv('foo.csv')
#read from csv
#pd.read_csv('foo.csv')
'''
normalizaiton
regularization
regression
auto regression
arma
statsmodels
time series
'''
