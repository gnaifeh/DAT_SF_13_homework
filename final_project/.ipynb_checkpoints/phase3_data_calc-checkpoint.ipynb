# %% [markdown]
# # Final Project: Phase 3: Manipulating Maps Data with Pandas

# %%
import numpy as np
import pandas as pd
import MySQLdb as mdb
import MySQL_data_file as MySQL_data

# %%
con = mdb.connect(MySQL_data.my_sql_host, MySQL_data.my_sql_user,\
                    MySQL_data.my_sql_passwd,\
                    MySQL_data.my_sql_database)
#con.close

# %%
def run_sql(query):
    cur = con.cursor()
    cur.execute(query)
    con.commit()
    #con.close()
    return cur.fetchall()

# %%
gmaps_df = pd.read_sql("""SELECT entry_id,timestamp,datetime,origins,destinations,travel_mode,duration,distance,fare
                        FROM gmaps_data""",con)
gmaps_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29628 entries, 0 to 29627
# Data columns (total 9 columns):
# entry_id        29628 non-null int64
# timestamp       29628 non-null datetime64[ns]
# datetime        29628 non-null datetime64[ns]
# origins         29628 non-null object
# destinations    29628 non-null object
# travel_mode     29628 non-null object
# duration        29454 non-null float64
# distance        29454 non-null float64
# fare            17128 non-null float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(3)
# memory usage: 2.3+ MB

# %%
bing_df = pd.read_sql("""SELECT entry_id,timestamp,datetime,origins,destinations,travel_mode,duration_traffic,distance,congestion
                        FROM mmaps_data""",con)
bing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19080 entries, 0 to 19079
# Data columns (total 9 columns):
# entry_id            19080 non-null int64
# timestamp           19080 non-null datetime64[ns]
# datetime            19080 non-null datetime64[ns]
# origins             19080 non-null object
# destinations        19080 non-null object
# travel_mode         19080 non-null object
# duration_traffic    19080 non-null int64
# distance            19080 non-null int64
# congestion          19080 non-null object
# dtypes: datetime64[ns](2), int64(3), object(4)
# memory usage: 1.5+ MB

# %%
#changing the bing maps "duration_traffic" column to "duration" in order to match up the column with the gmaps_df
bing_df.columns = [u'entry_id', u'timestamp', u'datetime', u'origins', u'destinations', u'travel_mode', u'duration', u'distance', u'congestion']

# %%
combined_df = gmaps_df.merge(bing_df, how='outer')

# %%
combined_df = combined_df.copy()

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48708 entries, 0 to 48707
# Data columns (total 10 columns):
# entry_id        48708 non-null float64
# timestamp       48708 non-null datetime64[ns]
# datetime        48708 non-null datetime64[ns]
# origins         48708 non-null object
# destinations    48708 non-null object
# travel_mode     48708 non-null object
# duration        48534 non-null float64
# distance        48534 non-null float64
# fare            17128 non-null float64
# congestion      19080 non-null object
# dtypes: datetime64[ns](2), float64(4), object(4)
# memory usage: 4.1+ MB

# %%
#can also use sql to look for null values: select * from gmaps_data where duration is NULL
combined_df = combined_df.ix[pd.notnull(combined_df['duration']),:].sort(columns='entry_id', ascending='True')

# %% [markdown]
# Note (from above): It appears that all data between April 22 and 25 was corrupted. Should delete or remove any references

# %%
print len(combined_df[pd.isnull(combined_df['duration'])])
print len(combined_df[pd.notnull(combined_df['duration'])])
# Out:
# 0
# 48534

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index:
# 37477                      Mountain View, CA     driving      2952        65
# 37527  Financial District, San Francisco, CA     driving      1702        18
# 37529                      Mountain View, CA     driving      2990        65
# 37579  Financial District, San Francisco, CA     driving      1713        18
# 37581                      Mountain View, CA     driving      2985        65
# 37631  Financial District, San Francisco, CA     driving      1727        18
# 37633                      Mountain View, CA     driving      2931        65
# 37683  Financial District, San Francisco, CA     driving      1341        18
# 37685                      Mountain View, CA     driving      2934        65
# 37735  Financial District, San Francisco, CA     driving      1345        18
# 37737                      Mountain View, CA     driving      2931        65
# 37787  Financial District, San Francisco, CA     driving      1330        18
# 37789                      Mountain View, CA     driving      2906        65
# 37839  Financial District, San Francisco, CA     driving      1377        18
# 37841                      Mountain View, CA     driving      2918        65
# 37891  Financial District, San Francisco, CA     driving      1447        18
# 37893                      Mountain View, CA     driving      2977        65
# 37943  Financial District, San Francisco, CA     driving      1554        18
# 37945                      Mountain View, CA     driving      3098        65
# 37995  Financial District, San Francisco, CA     driving      1686        18
# 37997                      Mountain View, CA     driving      3133        65
# 38047  Financial District, San Francisco, CA     driving      1881        18
# 38049                      Mountain View, CA     driving      3091        65
# 38099  Financial District, San Francisco, CA     driving      1847        18
# 38101                      Mountain View, CA     driving      3118        65
# 38151  Financial District, San Francisco, CA     driving      1843        18
# 38153                      Mountain View, CA     driving      3255        65
#
#        fare congestion
# 1       NaN       None
# 3       NaN       None
# 5       NaN       None
# 7       NaN       Mild
# 9       NaN       None
# 11      NaN       None
# 71      NaN       None
# 73      NaN       None
# 111     NaN       None
# 113     NaN       None
# 151     NaN       None
# 153     NaN       None
# 161     NaN       Mild
# 163     NaN       None
# 165     NaN       None
# 167     NaN       Mild
# 169     NaN       None
# 171     NaN       None
# 243     NaN       None
# 245     NaN       None
# 253     NaN       Mild
# 255     NaN       None
# 257     NaN       Mild
# 259     NaN       None
# 261     NaN       None
# 263     NaN       None
# 265     NaN       None
# 267     NaN       None
# 347     NaN       None
# 349     NaN       None
# ...     ...        ...
# 37423   NaN       Mild
# 37425   NaN       None
# 37475   NaN     Medium
# 37477   NaN       None
# 37527   NaN      Heavy
# 37529   NaN       None
# 37579   NaN      Heavy
# 37581   NaN       None
# 37631   NaN      Heavy
# 37633   NaN       None
# 37683   NaN       Mild
# 37685   NaN       None
# 37735   NaN       Mild
# 37737   NaN       None
# 37787   NaN       Mild
# 37789   NaN       None
# 37839   NaN     Medium
# 37841   NaN       None
# 37891   NaN     Medium
# 37893   NaN       None
# 37943   NaN     Medium
# 37945   NaN       Mild
# 37995   NaN      Heavy
# 37997   NaN       Mild
# 38047   NaN      Heavy
# 38049   NaN       Mild
# 38099   NaN      Heavy
# 38101   NaN       Mild
# 38151   NaN      Heavy
# 38153   NaN       Mild
#
# [3464 rows x 10 columns]
